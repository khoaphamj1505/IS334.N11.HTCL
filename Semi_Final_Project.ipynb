# %% [markdown]
# <a href="https://colab.research.google.com/github/khoaphamj1505/IS334.N11.HTCL/blob/main/Semi_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install underthesea
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting underthesea
#   Downloading underthesea-1.4.1-py3-none-any.whl (11.0 MB)
#      |████████████████████████████████| 11.0 MB 5.3 MB/s
# Collecting python-crfsuite>=0.9.6
#   Downloading python_crfsuite-0.9.8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 55.8 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from underthesea) (4.64.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from underthesea) (2.23.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.8/dist-packages (from underthesea) (6.0)
# Collecting underthesea-core==0.0.5a2
#   Downloading underthesea_core-0.0.5_alpha.2-cp38-cp38-manylinux2010_x86_64.whl (591 kB)
#      |████████████████████████████████| 591 kB 44.0 MB/s
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from underthesea) (1.2.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (from underthesea) (3.7)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from underthesea) (1.0.2)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.8/dist-packages (from underthesea) (7.1.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk->underthesea) (2022.6.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->underthesea) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->underthesea) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->underthesea) (2022.12.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->underthesea) (3.0.4)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->underthesea) (1.7.3)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->underthesea) (1.21.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->underthesea) (3.1.0)
# Installing collected packages: underthesea-core, python-crfsuite, underthesea
# Successfully installed python-crfsuite-0.9.8 underthesea-1.4.1 underthesea-core-0.0.5a2

# %%
# !pip install Flask
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Flask in /usr/local/lib/python3.8/dist-packages (1.1.4)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.8/dist-packages (from Flask) (7.1.2)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.8/dist-packages (from Flask) (1.0.1)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.8/dist-packages (from Flask) (1.1.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.8/dist-packages (from Flask) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from Jinja2<3.0,>=2.10.1->Flask) (2.0.1)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Libraries
import nltk
from underthesea import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from keras.utils.np_utils import to_categorical
import numpy as np
import tensorflow as tf
import keras
from tensorflow import keras
from tensorflow.keras import layers
import random
import pickle
import json
import re

# %%
patterns = {
	'[àáảãạăắằẵặẳâầấậẫẩ]': 'a',
	'[đ]': 'd',
	'[èéẻẽẹêềếểễệ]': 'e',
	'[ìíỉĩị]': 'i',
	'[òóỏõọôồốổỗộơờớởỡợ]': 'o',
	'[ùúủũụưừứửữự]': 'u',
	'[ỳýỷỹỵ]': 'y'
}

stop_words = ['bạn', 'ban', 'anh', 'chị', 'chi', 'em', 'shop', 'bot', 'ad']

def convert_to_no_accents(text):
	output = text
	for regex, replace in patterns.items():
		output = re.sub(regex, replace, output)
		output = re.sub(regex.upper(), replace.upper(), output)
	return output

# %%
trains = {}
with open('/content/drive/MyDrive/UIT/NĂM 4/E-commerce/PROJECT/data/intents.json', 'r', encoding='utf-8') as json_data:
	intents = json.load(json_data)
	for one_intent in intents['intents']:
		sentences = one_intent['patterns']
		trains[one_intent['tag']] = sentences
# print(trains)
classes = {}
X_train = []
y_train = []
for i, (key, value) in enumerate(trains.items()):
	X_train += [word_tokenize(v, format="text") for v in value] + [convert_to_no_accents(v) for v in value]
	y_train += [i]*len(value)*2
	classes[i] = key

pickle.dump(classes, open("/content/drive/MyDrive/UIT/NĂM 4/E-commerce/PROJECT/pkl/classes.pkl", "wb"))

y_train = to_categorical(y_train)

# print(X_train)
# print(y_train)
vectorizer = TfidfVectorizer(lowercase=True, stop_words=stop_words)
X_train = vectorizer.fit_transform(X_train).toarray()

# %%
pickle.dump(vectorizer, open("/content/drive/MyDrive/UIT/NĂM 4/E-commerce/PROJECT/pkl/tfidf_vectorizer.pkl", "wb"))
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(8, input_dim = X_train.shape[1] ))
model.add(tf.keras.layers.Dense(8))
model.add(tf.keras.layers.Dense(len(y_train[0]), activation='softmax'))
callbacks = [
	keras.callbacks.ModelCheckpoint('/content/drive/MyDrive/UIT/NĂM 4/E-commerce/PROJECT/pkl/model.h5', save_best_only=True),
]
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train, y_train, epochs=2000, batch_size=8, callbacks=callbacks)
model.save('/content/drive/MyDrive/UIT/NĂM 4/E-commerce/PROJECT/pkl/model.h5')
# Out:
# Epoch 1/2000
#  1/30 [>.............................] - ETA: 17s - loss: 0.0824
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 1s 2ms/step - loss: 0.0825
# Epoch 2/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0820
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0819
# Epoch 3/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0815
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0813
# Epoch 4/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0809
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0805
# Epoch 5/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0790
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0796
# Epoch 6/2000
# 30/30 [==============================] - ETA: 0s - loss: 0.0783
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0783
# Epoch 7/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0793
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0765
# Epoch 8/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0736
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0741
# Epoch 9/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0752
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0710
# Epoch 10/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0755
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0675
# Epoch 11/2000
# 30/30 [==============================] - ETA: 0s - loss: 0.0638
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0638
# Epoch 12/2000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.0593
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0599
# Epoch 13/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0462
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0558
# Epoch 14/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0713
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0517
# Epoch 15/2000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.0469
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0475
# Epoch 16/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0351
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0434
# Epoch 17/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0421
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0391
# Epoch 18/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0458
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0348
# Epoch 19/2000
# 29/30 [============================>.] - ETA: 0s - loss: 0.0304
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0307
# Epoch 20/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0267
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0268
# Epoch 21/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0137
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0234
# Epoch 22/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0227
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0204
# Epoch 23/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0069
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0179
# Epoch 24/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0378
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0160
# Epoch 25/2000
# 30/30 [==============================] - ETA: 0s - loss: 0.0143
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0143
# Epoch 26/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0169
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0129
# Epoch 27/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0126
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0118
# Epoch 28/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0050
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0107
# Epoch 29/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0084
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0098
# Epoch 30/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0062
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0090
# Epoch 31/2000
# 23/30 [======================>.......] - ETA: 0s - loss: 0.0092
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0082
# Epoch 32/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0068
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 33/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0012
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0070
# Epoch 34/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0122
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 35/2000
# 29/30 [============================>.] - ETA: 0s - loss: 0.0059
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 36/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0033
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0057
# Epoch 37/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0154
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0053
# Epoch 38/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0026
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0050
# Epoch 39/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0012
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0047
# Epoch 40/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0022
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0043
# Epoch 41/2000
#  1/30 [>.............................] - ETA: 0s - loss: 5.7233e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 42/2000
#  1/30 [>.............................] - ETA: 0s - loss: 5.8248e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0034
# Epoch 43/2000
# 30/30 [==============================] - ETA: 0s - loss: 0.0028
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 44/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0082
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 45/2000
#  1/30 [>.............................] - ETA: 0s - loss: 5.5200e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0020
# Epoch 46/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0039
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 47/2000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.0015
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 48/2000
#  1/30 [>.............................] - ETA: 0s - loss: 4.9272e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 49/2000
# 29/30 [============================>.] - ETA: 0s - loss: 0.0013
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 50/2000
#  1/30 [>.............................] - ETA: 0s - loss: 6.7906e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 51/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0011
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 52/2000
#  1/30 [>.............................] - ETA: 0s - loss: 6.2083e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 9.4547e-04
# Epoch 53/2000
#  1/30 [>.............................] - ETA: 0s - loss: 2.1958e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 8.7633e-04
# Epoch 54/2000
# 29/30 [============================>.] - ETA: 0s - loss: 8.2373e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 8.0765e-04
# Epoch 55/2000
#  1/30 [>.............................] - ETA: 0s - loss: 2.5826e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 7.4973e-04
# Epoch 56/2000
#  1/30 [>.............................] - ETA: 0s - loss: 2.5223e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 6.9949e-04
# Epoch 57/2000
#  1/30 [>.............................] - ETA: 0s - loss: 2.4208e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 6.5029e-04
# Epoch 58/2000
#  1/30 [>.............................] - ETA: 0s - loss: 2.1308e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 6.0688e-04
# Epoch 59/2000
# 29/30 [============================>.] - ETA: 0s - loss: 5.6100e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 5.6756e-04
# Epoch 60/2000
#  1/30 [>.............................] - ETA: 0s - loss: 3.0610e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 5.3347e-04
# Epoch 61/2000
#  1/30 [>.............................] - ETA: 0s - loss: 2.0558e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 4.9972e-04
# Epoch 62/2000
#  1/30 [>.............................] - ETA: 0s - loss: 0.0016
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 4.6988e-04
# Epoch 63/2000
# 27/30 [==========================>...] - ETA: 0s - loss: 4.4457e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 4.4221e-04
# Epoch 64/2000
# 26/30 [=========================>....] - ETA: 0s - loss: 4.4540e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 4.1713e-04
# Epoch 65/2000
#  1/30 [>.............................] - ETA: 0s - loss: 1.5948e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 3.9320e-04
# Epoch 66/2000
#  1/30 [>.............................] - ETA: 0s - loss: 1.5972e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 3.7299e-04
# Epoch 67/2000
# 29/30 [============================>.] - ETA: 0s - loss: 3.5898e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 3.5294e-04
# Epoch 68/2000
#  1/30 [>.............................] - ETA: 0s - loss: 1.6357e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 3.3380e-04
# Epoch 69/2000
# 30/30 [==============================] - ETA: 0s - loss: 3.1717e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 3.1717e-04
# Epoch 70/2000
# 29/30 [============================>.] - ETA: 0s - loss: 3.0704e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 3.0144e-04
# Epoch 71/2000
#  1/30 [>.............................] - ETA: 0s - loss: 2.1354e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.8625e-04
# Epoch 72/2000
#  1/30 [>.............................] - ETA: 0s - loss: 1.1687e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.7275e-04
# Epoch 73/2000
#  1/30 [>.............................] - ETA: 0s - loss: 1.3149e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.5976e-04
# Epoch 74/2000
#  1/30 [>.............................] - ETA: 0s - loss: 8.2702e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.4722e-04
# Epoch 75/2000
# 25/30 [========================>.....] - ETA: 0s - loss: 2.4680e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.3651e-04
# Epoch 76/2000
#  1/30 [>.............................] - ETA: 0s - loss: 2.3769e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.2490e-04
# Epoch 77/2000
# 28/30 [===========================>..] - ETA: 0s - loss: 2.2391e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1485e-04
# Epoch 78/2000
#  1/30 [>.............................] - ETA: 0s - loss: 6.7309e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0556e-04
# Epoch 79/2000
# 30/30 [==============================] - ETA: 0s - loss: 1.9686e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.9686e-04
# Epoch 80/2000
# 30/30 [==============================] - ETA: 0s - loss: 1.8850e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.8850e-04
# Epoch 81/2000
# 30/30 [==============================] - ETA: 0s - loss: 1.8107e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.8107e-04
# Epoch 82/2000
# 29/30 [============================>.] - ETA: 0s - loss: 1.7520e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.7335e-04
# Epoch 83/2000
#  1/30 [>.............................] - ETA: 0s - loss: 8.8295e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.6654e-04
# Epoch 84/2000
#  1/30 [>.............................] - ETA: 0s - loss: 8.7484e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.5961e-04
# Epoch 85/2000
#  1/30 [>.............................] - ETA: 0s - loss: 2.5306e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.5333e-04
# Epoch 86/2000
#  1/30 [>.............................] - ETA: 0s - loss: 1.6508e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.4784e-04
# Epoch 87/2000
# 28/30 [===========================>..] - ETA: 0s - loss: 1.3660e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.4191e-04
# Epoch 88/2000
#  1/30 [>.............................] - ETA: 0s - loss: 1.0590e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3681e-04
# Epoch 89/2000
#  1/30 [>.............................] - ETA: 0s - loss: 1.1199e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3147e-04
# Epoch 90/2000
#  1/30 [>.............................] - ETA: 0s - loss: 1.0060e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2718e-04
# Epoch 91/2000
#  1/30 [>.............................] - ETA: 0s - loss: 7.1623e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2242e-04
# Epoch 92/2000
#  1/30 [>.............................] - ETA: 0s - loss: 4.8580e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1762e-04
# Epoch 93/2000
#  1/30 [>.............................] - ETA: 0s - loss: 3.7716e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1392e-04
# Epoch 94/2000
# 29/30 [============================>.] - ETA: 0s - loss: 1.0803e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0978e-04
# Epoch 95/2000
# 28/30 [===========================>..] - ETA: 0s - loss: 1.0654e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0597e-04
# Epoch 96/2000
# 27/30 [==========================>...] - ETA: 0s - loss: 1.0627e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0239e-04
# Epoch 97/2000
#  1/30 [>.............................] - ETA: 0s - loss: 4.4815e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 9.8946e-05
# Epoch 98/2000
#  1/30 [>.............................] - ETA: 0s - loss: 6.2042e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 9.5605e-05
# Epoch 99/2000
#  1/30 [>.............................] - ETA: 0s - loss: 1.7202e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 9.2572e-05
# Epoch 100/2000
# 26/30 [=========================>....] - ETA: 0s - loss: 8.2058e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 8.9368e-05
# Epoch 101/2000
#  1/30 [>.............................] - ETA: 0s - loss: 5.8785e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 8.6491e-05
# Epoch 102/2000
#  1/30 [>.............................] - ETA: 0s - loss: 7.6044e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 8.3841e-05
# Epoch 103/2000
#  1/30 [>.............................] - ETA: 0s - loss: 2.4106e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 8.1071e-05
# Epoch 104/2000
# 30/30 [==============================] - ETA: 0s - loss: 7.8708e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 7.8708e-05
# Epoch 105/2000
# 26/30 [=========================>....] - ETA: 0s - loss: 7.6047e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 7.6351e-05
# Epoch 106/2000
#  1/30 [>.............................] - ETA: 0s - loss: 2.2986e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 7.3856e-05
# Epoch 107/2000
#  1/30 [>.............................] - ETA: 0s - loss: 4.2122e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 7.1491e-05
# Epoch 108/2000
#  1/30 [>.............................] - ETA: 0s - loss: 4.3225e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 6.9446e-05
# Epoch 109/2000
#  1/30 [>.............................] - ETA: 0s - loss: 3.4068e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 6.7363e-05
# Epoch 110/2000
# 24/30 [=======================>......] - ETA: 0s - loss: 6.5925e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 6.5352e-05
# Epoch 111/2000
#  1/30 [>.............................] - ETA: 0s - loss: 6.3021e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 6.3485e-05
# Epoch 112/2000
# 30/30 [==============================] - ETA: 0s - loss: 6.1638e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 6.1638e-05
# Epoch 113/2000
#  1/30 [>.............................] - ETA: 0s - loss: 2.1944e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 6.0105e-05
# Epoch 114/2000
#  1/30 [>.............................] - ETA: 0s - loss: 5.2467e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 5.8247e-05
# Epoch 115/2000
# 26/30 [=========================>....] - ETA: 0s - loss: 5.0776e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 5.6457e-05
# Epoch 116/2000
#  1/30 [>.............................] - ETA: 0s - loss: 3.6167e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 5.4914e-05
# Epoch 117/2000
#  1/30 [>.............................] - ETA: 0s - loss: 3.3381e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 5.3320e-05
# Epoch 118/2000
#  1/30 [>.............................] - ETA: 0s - loss: 1.6506e-04
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 5.2011e-05
# Epoch 119/2000
#  1/30 [>.............................] - ETA: 0s - loss: 3.7010e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 5.0462e-05
# Epoch 120/2000
#  1/30 [>.............................] - ETA: 0s - loss: 3.7671e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 4.9077e-05
# Epoch 121/2000
#  1/30 [>.............................] - ETA: 0s - loss: 4.9688e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 4.7728e-05
# Epoch 122/2000
#  1/30 [>.............................] - ETA: 0s - loss: 3.9447e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 4.6476e-05
# Epoch 123/2000
#  1/30 [>.............................] - ETA: 0s - loss: 2.2194e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 4.5240e-05
# Epoch 124/2000
#  1/30 [>.............................] - ETA: 0s - loss: 4.6055e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 4.4113e-05
# Epoch 125/2000
# 29/30 [============================>.] - ETA: 0s - loss: 4.3357e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 4.2928e-05
# Epoch 126/2000
# 25/30 [========================>.....] - ETA: 0s - loss: 4.5395e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 4.1800e-05
# Epoch 127/2000
#  1/30 [>.............................] - ETA: 0s - loss: 6.6151e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 4.0602e-05
# Epoch 128/2000
#  1/30 [>.............................] - ETA: 0s - loss: 1.2298e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 3.9601e-05
# Epoch 129/2000
#  1/30 [>.............................] - ETA: 0s - loss: 4.0663e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 3.8613e-05
# Epoch 130/2000
# 26/30 [=========================>....] - ETA: 0s - loss: 4.0128e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 3.7570e-05
# Epoch 131/2000
#  1/30 [>.............................] - ETA: 0s - loss: 1.1259e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 3.6677e-05
# Epoch 132/2000
#  1/30 [>.............................] - ETA: 0s - loss: 9.3083e-06
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 3.5756e-05
# Epoch 133/2000
#  1/30 [>.............................] - ETA: 0s - loss: 3.4750e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 3.4870e-05
# Epoch 134/2000
#  1/30 [>.............................] - ETA: 0s - loss: 2.6744e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 3.3983e-05
# Epoch 135/2000
# 30/30 [==============================] - ETA: 0s - loss: 3.3166e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 3.3166e-05
# Epoch 136/2000
#  1/30 [>.............................] - ETA: 0s - loss: 8.7133e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 3.2274e-05
# Epoch 137/2000
#  1/30 [>.............................] - ETA: 0s - loss: 1.9485e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 3.1501e-05
# Epoch 138/2000
#  1/30 [>.............................] - ETA: 0s - loss: 2.2311e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 3.0774e-05
# Epoch 139/2000
#  1/30 [>.............................] - ETA: 0s - loss: 2.1725e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 3.0137e-05
# Epoch 140/2000
# 28/30 [===========================>..] - ETA: 0s - loss: 3.0047e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.9261e-05
# Epoch 141/2000
# 29/30 [============================>.] - ETA: 0s - loss: 2.8732e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.8605e-05
# Epoch 142/2000
# 26/30 [=========================>....] - ETA: 0s - loss: 2.6891e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.7926e-05
# Epoch 143/2000
#  1/30 [>.............................] - ETA: 0s - loss: 2.6103e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.7283e-05
# Epoch 144/2000
# 29/30 [============================>.] - ETA: 0s - loss: 2.6928e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.6605e-05
# Epoch 145/2000
# 27/30 [==========================>...] - ETA: 0s - loss: 2.7539e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.5996e-05
# Epoch 146/2000
# 30/30 [==============================] - ETA: 0s - loss: 2.5373e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.5373e-05
# Epoch 147/2000
#  1/30 [>.............................] - ETA: 0s - loss: 1.3222e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.4792e-05
# Epoch 148/2000
#  1/30 [>.............................] - ETA: 0s - loss: 1.0888e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.4209e-05
# Epoch 149/2000
#  1/30 [>.............................] - ETA: 0s - loss: 1.8774e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.3654e-05
# Epoch 150/2000
# 29/30 [============================>.] - ETA: 0s - loss: 2.3297e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.3123e-05
# Epoch 151/2000
# 30/30 [==============================] - ETA: 0s - loss: 2.2597e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.2597e-05
# Epoch 152/2000
#  1/30 [>.............................] - ETA: 0s - loss: 1.8911e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.2063e-05
# Epoch 153/2000
#  1/30 [>.............................] - ETA: 0s - loss: 1.9505e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1587e-05
# Epoch 154/2000
#  1/30 [>.............................] - ETA: 0s - loss: 2.4029e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1063e-05
# Epoch 155/2000
# 23/30 [======================>.......] - ETA: 0s - loss: 1.8745e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.0629e-05
# Epoch 156/2000
# 25/30 [========================>.....] - ETA: 0s - loss: 2.2091e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0172e-05
# Epoch 157/2000
# 30/30 [==============================] - ETA: 0s - loss: 1.9694e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.9694e-05
# Epoch 158/2000
#  1/30 [>.............................] - ETA: 0s - loss: 1.0112e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.9256e-05
# Epoch 159/2000
#  1/30 [>.............................] - ETA: 0s - loss: 7.4239e-06
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.8809e-05
# Epoch 160/2000
# 28/30 [===========================>..] - ETA: 0s - loss: 1.8928e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.8433e-05
# Epoch 161/2000
#  1/30 [>.............................] - ETA: 0s - loss: 8.2090e-06
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.8027e-05
# Epoch 162/2000
#  1/30 [>.............................] - ETA: 0s - loss: 1.4012e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.7637e-05
# Epoch 163/2000
#  1/30 [>.............................] - ETA: 0s - loss: 5.8158e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.7241e-05
# Epoch 164/2000
#  1/30 [>.............................] - ETA: 0s - loss: 1.7281e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.6885e-05
# Epoch 165/2000
# 26/30 [=========================>....] - ETA: 0s - loss: 1.6974e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.6617e-05
# Epoch 166/2000
# 30/30 [==============================] - ETA: 0s - loss: 1.6138e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.6138e-05
# Epoch 167/2000
#  1/30 [>.............................] - ETA: 0s - loss: 1.0171e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.5787e-05
# Epoch 168/2000
#  1/30 [>.............................] - ETA: 0s - loss: 1.0564e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.5462e-05
# Epoch 169/2000
#  1/30 [>.............................] - ETA: 0s - loss: 4.6891e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.5128e-05
# Epoch 170/2000
# 30/30 [==============================] - ETA: 0s - loss: 1.4808e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.4808e-05
# Epoch 171/2000
# 25/30 [========================>.....] - ETA: 0s - loss: 1.4402e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.4483e-05
# Epoch 172/2000
#  1/30 [>.............................] - ETA: 0s - loss: 6.0044e-06
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.4208e-05
# Epoch 173/2000
#  1/30 [>.............................] - ETA: 0s - loss: 7.5754e-06
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3894e-05
# Epoch 174/2000
# 23/30 [======================>.......] - ETA: 0s - loss: 1.3715e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3609e-05
# Epoch 175/2000
# 27/30 [==========================>...] - ETA: 0s - loss: 1.3204e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3355e-05
# Epoch 176/2000
# 30/30 [==============================] - ETA: 0s - loss: 1.3030e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3030e-05
# Epoch 177/2000
#  1/30 [>.............................] - ETA: 0s - loss: 1.6052e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2770e-05
# Epoch 178/2000
#  1/30 [>.............................] - ETA: 0s - loss: 3.9379e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2502e-05
# Epoch 179/2000
# 29/30 [============================>.] - ETA: 0s - loss: 1.2351e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2242e-05
# Epoch 180/2000
#  1/30 [>.............................] - ETA: 0s - loss: 5.8376e-06
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1992e-05
# Epoch 181/2000
# 30/30 [==============================] - ETA: 0s - loss: 1.1758e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1758e-05
# Epoch 182/2000
#  1/30 [>.............................] - ETA: 0s - loss: 1.0321e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1511e-05
# Epoch 183/2000
# 30/30 [==============================] - ETA: 0s - loss: 1.1277e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1277e-05
# Epoch 184/2000
# 30/30 [==============================] - ETA: 0s - loss: 1.1060e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1060e-05
# Epoch 185/2000
#  1/30 [>.............................] - ETA: 0s - loss: 1.6182e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0834e-05
# Epoch 186/2000
# 26/30 [=========================>....] - ETA: 0s - loss: 1.0247e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0599e-05
# Epoch 187/2000
#  1/30 [>.............................] - ETA: 0s - loss: 1.2918e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0387e-05
# Epoch 188/2000
#  1/30 [>.............................] - ETA: 0s - loss: 1.0123e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0181e-05
# Epoch 189/2000
# 28/30 [===========================>..] - ETA: 0s - loss: 1.0183e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 9.9700e-06
# Epoch 190/2000
# 29/30 [============================>.] - ETA: 0s - loss: 9.9721e-06
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 9.7991e-06
# Epoch 191/2000
# 30/30 [==============================] - ETA: 0s - loss: 9.5725e-06
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 9.5725e-06
# Epoch 192/2000
#  1/30 [>.............................] - ETA: 0s - loss: 2.3842e-05
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 9.3894e-06
# Epoch 193/2000
# 26/30 [=========================>....] - ETA: 0s - loss: 9.1750e-06
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 9.2102e-06
# Epoch 194/2000
#  1/30 [>.............................] - ETA: 0s - loss: 2.8937e-06
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 9.0243e-06
# Epoch 195/2000
# 30/30 [==============================] - ETA: 0s - loss: 8.8399e-06
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 8.8399e-06
# Epoch 196/2000
# 29/30 [============================>.] - ETA: 0s - loss: 8.1247e-06
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 8.6676e-06
# Epoch 197/2000
# 30/30 [==============================] - ETA: 0s - loss: 8.4993e-06
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 8.4993e-06
# Epoch 198/2000
# 29/30 [============================>.] - ETA: 0s - loss: 7.6704e-06
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 8.3302e-06
# Epoch 199/2000
# 27/30 [==========================>...] - ETA: 0s - loss: 8.5331e-06
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 8.1620e-06
# Epoch 200/2000
# 29/30 [============================>.] - ETA: 0s - loss: 8.1872e-06
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 8.0113e-06
# Epoch 201/2000
# 22/30 [=====================>........] - ETA: 0s - loss: 7.8830e-06
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 7.8516e-06
# Epoch 202/2000
# 30/30 [==============================] - ETA: 0s - loss: 7.6983e-06
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 7.6983e-06
# Epoch 203/2000
# 26/30 [=========================>....] - ETA: 0s - loss: 7.9347e-06
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 7.5590e-06
# Epoch 204/2000
# 30/30 [==============================] - ETA: 0s - loss: 7.4011e-06
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 7.4011e-06
# Epoch 205/2000
# 28/30 [===========================>..] - ETA: 0s - loss: 7.5616e-06
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 7.2744e-06
# Epoch 206/2000
# 30/30 [==============================] - ETA: 0s - loss: 7.1144e-06
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 7.1144e-06
# Epoch 207/2000
# 28/30 [===========================>..] - ETA: 0s - loss: 6.5702e-06
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 6.9805e-06
# Epoch 208/2000
# ...
# Epoch 1933/2000
# 23/30 [======================>.......] - ETA: 0s - loss: 2.3708e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1806e-10
# Epoch 1934/2000
# 21/30 [====================>.........] - ETA: 0s - loss: 2.1290e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1787e-10
# Epoch 1935/2000
# 19/30 [==================>...........] - ETA: 0s - loss: 1.9466e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1772e-10
# Epoch 1936/2000
# 23/30 [======================>.......] - ETA: 0s - loss: 2.2758e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1750e-10
# Epoch 1937/2000
# 22/30 [=====================>........] - ETA: 0s - loss: 1.8705e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1739e-10
# Epoch 1938/2000
# 19/30 [==================>...........] - ETA: 0s - loss: 2.1633e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1720e-10
# Epoch 1939/2000
# 19/30 [==================>...........] - ETA: 0s - loss: 2.3483e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1704e-10
# Epoch 1940/2000
# 21/30 [====================>.........] - ETA: 0s - loss: 2.1854e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1686e-10
# Epoch 1941/2000
# 21/30 [====================>.........] - ETA: 0s - loss: 2.1381e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1667e-10
# Epoch 1942/2000
# 21/30 [====================>.........] - ETA: 0s - loss: 2.2585e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1651e-10
# Epoch 1943/2000
# 21/30 [====================>.........] - ETA: 0s - loss: 2.2599e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1637e-10
# Epoch 1944/2000
# 19/30 [==================>...........] - ETA: 0s - loss: 2.0050e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1615e-10
# Epoch 1945/2000
# 21/30 [====================>.........] - ETA: 0s - loss: 2.4077e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1592e-10
# Epoch 1946/2000
# 20/30 [===================>..........] - ETA: 0s - loss: 1.9279e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1573e-10
# Epoch 1947/2000
# 20/30 [===================>..........] - ETA: 0s - loss: 2.0342e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1558e-10
# Epoch 1948/2000
# 20/30 [===================>..........] - ETA: 0s - loss: 2.3362e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1545e-10
# Epoch 1949/2000
# 23/30 [======================>.......] - ETA: 0s - loss: 1.9690e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1536e-10
# Epoch 1950/2000
# 23/30 [======================>.......] - ETA: 0s - loss: 2.2978e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1511e-10
# Epoch 1951/2000
# 23/30 [======================>.......] - ETA: 0s - loss: 2.1364e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1492e-10
# Epoch 1952/2000
# 22/30 [=====================>........] - ETA: 0s - loss: 2.3654e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1473e-10
# Epoch 1953/2000
# 23/30 [======================>.......] - ETA: 0s - loss: 2.0033e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1450e-10
# Epoch 1954/2000
# 22/30 [=====================>........] - ETA: 0s - loss: 1.9283e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1433e-10
# Epoch 1955/2000
# 23/30 [======================>.......] - ETA: 0s - loss: 2.2467e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1421e-10
# Epoch 1956/2000
# 21/30 [====================>.........] - ETA: 0s - loss: 1.9229e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1401e-10
# Epoch 1957/2000
# 24/30 [=======================>......] - ETA: 0s - loss: 2.2882e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1380e-10
# Epoch 1958/2000
# 23/30 [======================>.......] - ETA: 0s - loss: 2.2792e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1361e-10
# Epoch 1959/2000
# 25/30 [========================>.....] - ETA: 0s - loss: 1.9170e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1350e-10
# Epoch 1960/2000
# 21/30 [====================>.........] - ETA: 0s - loss: 2.1695e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1336e-10
# Epoch 1961/2000
# 23/30 [======================>.......] - ETA: 0s - loss: 2.1677e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1321e-10
# Epoch 1962/2000
# 24/30 [=======================>......] - ETA: 0s - loss: 2.0625e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1305e-10
# Epoch 1963/2000
# 24/30 [=======================>......] - ETA: 0s - loss: 2.2194e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1294e-10
# Epoch 1964/2000
# 25/30 [========================>.....] - ETA: 0s - loss: 1.9642e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1276e-10
# Epoch 1965/2000
# 22/30 [=====================>........] - ETA: 0s - loss: 2.1801e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1250e-10
# Epoch 1966/2000
# 23/30 [======================>.......] - ETA: 0s - loss: 2.3337e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1233e-10
# Epoch 1967/2000
# 24/30 [=======================>......] - ETA: 0s - loss: 2.1935e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1225e-10
# Epoch 1968/2000
# 25/30 [========================>.....] - ETA: 0s - loss: 2.1919e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1202e-10
# Epoch 1969/2000
# 22/30 [=====================>........] - ETA: 0s - loss: 2.1246e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1186e-10
# Epoch 1970/2000
# 19/30 [==================>...........] - ETA: 0s - loss: 2.1585e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1161e-10
# Epoch 1971/2000
# 22/30 [=====================>........] - ETA: 0s - loss: 2.2625e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1145e-10
# Epoch 1972/2000
# 24/30 [=======================>......] - ETA: 0s - loss: 1.7666e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1133e-10
# Epoch 1973/2000
# 22/30 [=====================>........] - ETA: 0s - loss: 2.3282e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1113e-10
# Epoch 1974/2000
# 27/30 [==========================>...] - ETA: 0s - loss: 1.9691e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1093e-10
# Epoch 1975/2000
# 23/30 [======================>.......] - ETA: 0s - loss: 2.2839e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1077e-10
# Epoch 1976/2000
# 22/30 [=====================>........] - ETA: 0s - loss: 2.1136e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1060e-10
# Epoch 1977/2000
# 25/30 [========================>.....] - ETA: 0s - loss: 2.0140e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1045e-10
# Epoch 1978/2000
# 26/30 [=========================>....] - ETA: 0s - loss: 2.2507e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1035e-10
# Epoch 1979/2000
# 25/30 [========================>.....] - ETA: 0s - loss: 2.1193e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1021e-10
# Epoch 1980/2000
# 26/30 [=========================>....] - ETA: 0s - loss: 2.0533e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0999e-10
# Epoch 1981/2000
# 24/30 [=======================>......] - ETA: 0s - loss: 2.1642e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.0981e-10
# Epoch 1982/2000
# 26/30 [=========================>....] - ETA: 0s - loss: 2.1729e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0957e-10
# Epoch 1983/2000
# 23/30 [======================>.......] - ETA: 0s - loss: 2.3507e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.0947e-10
# Epoch 1984/2000
# 20/30 [===================>..........] - ETA: 0s - loss: 2.0298e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.0925e-10
# Epoch 1985/2000
# 23/30 [======================>.......] - ETA: 0s - loss: 2.1532e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.0914e-10
# Epoch 1986/2000
# 29/30 [============================>.] - ETA: 0s - loss: 2.1034e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0894e-10
# Epoch 1987/2000
# 26/30 [=========================>....] - ETA: 0s - loss: 2.1609e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0886e-10
# Epoch 1988/2000
# 17/30 [================>.............] - ETA: 0s - loss: 2.0755e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.0862e-10
# Epoch 1989/2000
# 19/30 [==================>...........] - ETA: 0s - loss: 1.8122e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.0841e-10
# Epoch 1990/2000
# 21/30 [====================>.........] - ETA: 0s - loss: 2.1688e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.0831e-10
# Epoch 1991/2000
# 19/30 [==================>...........] - ETA: 0s - loss: 1.9410e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.0821e-10
# Epoch 1992/2000
# 17/30 [================>.............] - ETA: 0s - loss: 2.1304e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.0800e-10
# Epoch 1993/2000
# 23/30 [======================>.......] - ETA: 0s - loss: 2.0694e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.0787e-10
# Epoch 1994/2000
# 14/30 [=============>................] - ETA: 0s - loss: 1.6601e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.0772e-10
# Epoch 1995/2000
# 17/30 [================>.............] - ETA: 0s - loss: 2.2695e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.0751e-10
# Epoch 1996/2000
# 19/30 [==================>...........] - ETA: 0s - loss: 2.0331e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.0729e-10
# Epoch 1997/2000
# 18/30 [=================>............] - ETA: 0s - loss: 2.3182e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.0721e-10
# Epoch 1998/2000
# 16/30 [===============>..............] - ETA: 0s - loss: 2.0318e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.0701e-10
# Epoch 1999/2000
# 18/30 [=================>............] - ETA: 0s - loss: 2.0566e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.0678e-10
# Epoch 2000/2000
# 17/30 [================>.............] - ETA: 0s - loss: 1.9095e-10
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 30/30 [==============================] - 0s 3ms/step - loss: 2.0657e-10

# %%
def classify(sentence):
  sentence = word_tokenize(sentence, format="text")
  #print("test:", sentence, vectorizer)
  results = model.predict(vectorizer.transform([sentence]).toarray())[0]
  results = np.array(results)
  #print("kq", results)
  idx = np.argsort(-results)[0]
  return classes[idx], results[idx]

def response(tag):
	for i in intents['intents']:
		if i['tag'] == tag:
			return random.choice(i['responses'])

# %%
# !pip freeze > requirements.txt

# %%
print('Customer: ', end=''),
x = input()
tag, _ = classify(x)
print('Bot: ', response(tag))
# Out:
# Customer:

# %%
model.variables
# Out:
# [<tf.Variable 'dense/kernel:0' shape=(263, 8) dtype=float32, numpy=
#  array([[ 0.1602011 , -0.26679322,  0.0583946 , ..., -0.38769677,
#           0.03155598,  0.16112709],
#         [-0.48468798, -0.3280758 ,  0.38731623, ...,  0.42620888,
#           0.34061193,  0.34308475],
#         [ 0.3996071 ,  0.38837415,  0.34206203, ..., -0.16413112,
#           0.27245456,  0.32396096],
#         ...,
#         [ 0.08988133,  0.14227767,  0.5386808 , ..., -0.4363638 ,
#           0.01739954,  0.01594614],
#         [-0.19551614,  0.4116439 , -0.4991519 , ...,  0.42017323,
#          -0.44970816,  0.47476807],
#         [ 0.22844957, -0.30604437, -0.20241676, ...,  0.00223325,
#          -0.17084134, -0.3658561 ]], dtype=float32)>,
#  <tf.Variable 'dense/bias:0' shape=(8,) dtype=float32, numpy=
#  array([ 0.24174157,  0.2261441 ,  0.20843802, -0.3381541 ,  0.35836574,
#         -0.2516421 ,  0.289947  ,  0.14155011], dtype=float32)>,
#  <tf.Variable 'dense_1/kernel:0' shape=(8, 8) dtype=float32, numpy=
#  array([[-1.6607368 ,  0.76433426, -1.2094967 ,  1.9615215 , -1.209834  ,
#          -0.24160981, -1.7457442 , -1.2632122 ],
#         [ 1.775495  , -0.8233507 , -2.499813  , -0.10448831,  2.3140817 ,
#          -0.29684064, -0.6035882 ,  1.8919326 ],
#         [ 1.2662796 , -1.0726686 ,  1.8136636 , -1.0628251 , -0.6734376 ,
#          -2.3189878 , -0.67341346,  1.5012686 ],
#         [-0.881224  , -2.285618  ,  0.5125629 ,  1.544145  ,  0.5247092 ,
#          -1.7551217 , -0.05374533, -1.2950518 ],
#         [ 1.5539733 , -0.31329128, -1.0310038 ,  1.1765676 , -1.8816259 ,
#           1.2831429 , -2.090841  , -0.5424606 ],
#         [ 1.5055939 , -0.14455466,  0.03248098, -0.15549827,  0.44062027,
#           1.0593824 ,  2.4867492 ,  0.3428691 ],
#         [-1.3241582 ,  2.1389248 ,  1.0968741 , -1.7676358 , -0.21523933,
#          -0.29404444, -0.9168405 ,  1.7723889 ],
#         [-0.9020898 ,  0.8413239 ,  1.1628194 ,  0.72960436,  0.26592574,
#          -2.1387792 ,  0.44229072,  1.775716  ]], dtype=float32)>,
#  <tf.Variable 'dense_1/bias:0' shape=(8,) dtype=float32, numpy=
#  array([ 0.14128499,  0.21963614, -0.22977139, -0.06497893, -0.20286243,
#         -0.13944674, -0.30797923,  0.29754645], dtype=float32)>,
#  <tf.Variable 'dense_2/kernel:0' shape=(8, 11) dtype=float32, numpy=
#  array([[ 0.82697886, -1.8477987 ,  0.61568034, -0.6696576 , -0.71187615,
#           1.8925489 ,  0.7602256 ,  0.2817384 ,  1.4152796 ,  0.04189447,
#           0.8749433 ],
#         [ 1.1930836 ,  0.41338807,  0.7769324 ,  1.1183565 ,  1.5936171 ,
#          -1.080063  , -0.79846716, -1.32348   , -1.1918322 , -0.8653459 ,
#           0.49497226],
#         [-1.2896472 ,  1.4769273 , -1.4334706 , -0.69024014,  1.1161242 ,
#           0.58484054, -1.3710371 ,  0.22998296, -0.23953374,  0.9247738 ,
#           1.6237316 ],
#         [ 0.12538148,  0.5889951 , -1.2982289 ,  0.78078383, -0.5090004 ,
#          -0.76917994,  1.1192442 ,  0.84021914,  0.909517  , -0.4673469 ,
#          -0.65260655],
#         [-0.9211894 , -0.5884927 ,  1.2099612 , -0.81443137, -1.4610075 ,
#          -1.3648114 ,  0.8010066 , -1.3619763 ,  0.8205565 ,  1.1071874 ,
#           0.18005402],
#         [-0.7154633 , -1.3852749 ,  1.0231563 ,  1.7839968 ,  1.3269589 ,
#           1.4185609 ,  1.8655906 , -0.75150454, -1.2145268 , -1.3725103 ,
#          -0.14026757],
#         [-1.4674807 , -0.27780855,  1.0678228 , -0.4083465 ,  1.2698488 ,
#           0.28626487,  0.42749876, -0.79106855,  1.7203928 , -0.31749007,
#           2.0337303 ],
#         [ 1.4097182 , -0.11398344,  0.9659267 , -1.3847812 ,  0.3654315 ,
#           0.34569025, -0.81542313, -1.386772  ,  0.15023421,  1.0986981 ,
#           0.83438104]], dtype=float32)>,
#  <tf.Variable 'dense_2/bias:0' shape=(11,) dtype=float32, numpy=
#  array([ 0.33337206,  0.02220675,  0.03406457, -0.15165254,  0.08782243,
#         -0.06010568, -0.00278067, -0.06360804, -0.00333002, -0.10383298,
#         -0.23731197], dtype=float32)>]
